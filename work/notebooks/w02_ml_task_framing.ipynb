# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Goutam16-Withcode/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/Goutam16-Withcode/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship/flyrank-ml-internship
# Starter data found. You're ready.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# This is a ranking/scoring task, not classification. The output isn't "is this page
# declining: yes/no" in isolation -- it's "of all the pages, which ones should a content
# strategist look at first?" That's a ranked list problem, evaluated by precision@K, which
# is exactly the shape Notebook 02 used (hand rule vs. tree, compared at Precision@50).

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The proxy target is `is_declining_label` in the starter pipeline logic -- derived from
# `trend_direction == "down"`, itself computed from `trend_pct`, an OBSERVED outcome (a real
# measured change in traffic), not a product-defined rule. Per the data skill notes,
# `trend_direction` and `trend_pct` can never be features, only the source of the label.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Precision@50: of the top 50 pages a ranking flags for review, what fraction are actually
# declining. This is defensible because it mirrors the real constraint -- a strategist can
# only review so many pages a week, so getting the TOP of the list right matters more than
# overall accuracy across all 30,000 pages.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

lane_cols = ["content_id", "client_id", "trend_direction", "trend_pct",
             "days_since_last_update", "impressions_90d", "avg_position", "word_count"]
lane_slice = df[lane_cols]
print(f"{len(lane_slice):,} rows -- one row = one pseudonymized content page")
lane_slice.head(5)
# Out:
# 30,000 rows -- one row = one pseudonymized content page
#              content_id          client_id trend_direction  trend_pct  \
# 0  content_304f48230142  client_f369cb89fc            down      -41.4
# 1  content_a1fb4e703a9e  client_4e07408562            down      -57.7
# 2  content_9aa793d4d895  client_7f2253d7e2            down      -60.9
# 3  content_331d6c4de07b  client_19581e27de          stable      -13.8
# 4  content_d99b7a2d90ca  client_3fdba35f04            down      -34.7
#
#    days_since_last_update  impressions_90d  avg_position  word_count
# 0                      20             3803          10.6      3221.0
# 1                      25            15320          20.3      2481.0
# 2                      20            12581          36.5      3515.0
# 3                      22            11751           6.2         NaN
# 4                      14            19140          44.0      2803.0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Notebook 02 already showed this empirically: a single hand-written rule (stale x visible)
# and a depth-2 tree landed close on Precision@50, but the tree found threshold combinations
# across multiple signals (age, position, impressions) that aren't obvious to write by hand.
# As more signals get added (query diversity, position volatility, etc.), the number of
# interacting thresholds grows past what a human can reliably hand-tune -- that's exactly
# the "too messy for an if-statement" case the framing skill describes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
